# %% [markdown]
# Setting up PySpark in Colab
#
# Spark is written in the Scala programming language and requires the Java Virtual Machine (JVM) to run. Therefore, our first task is to download Java

# %%
# !sudo apt-get update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [45.4 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:16 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,732 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,929 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,360 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,391 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,162 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [886 kB]
# Fetched 10.8 MB in 3s (4,079 kB/s)
# Reading package lists... Done

# %% [markdown]
# Next, we will install Apache Spark 3.0.1 with Hadoop 2.7

# %%
# !wget -q https://www-us.apache.org/dist/spark/spark-3.0.1/spark-3.0.1-bin-hadoop2.7.tgz

# %% [markdown]
# Now, we just need to unzip that folder.

# %%
# !tar xf spark-3.0.1-bin-hadoop2.7.tgz

# %% [markdown]
# There is one last thing that we need to install and that is the findspark library. It will locate Spark on the system and import it as a regular library.

# %%
# !pip install -q findspark

# %% [markdown]
# Now that we have installed all the necessary dependencies in Colab, it is time to set the environment path. This will enable us to run Pyspark in the Colab environment.

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.1-bin-hadoop2.7"

# %% [markdown]
# We need to locate Spark in the system. For that, we import findspark and use the findspark.init() method.

# %%
import findspark
findspark.init()

# %% [markdown]
# If you want to know the location where Spark is installed, use findspark.find()

# %%
findspark.find()
# Out:
# '/content/spark-3.0.1-bin-hadoop2.7'

# %% [markdown]
# Now, we can import SparkSession from pyspark.sql and create a SparkSession, which is the entry point to Spark.
#
# You can give a name to the session using appName() and add some configurations with config() if you wish.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder\
        .master("local")\
        .appName("Colab")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()

# %% [markdown]
# Finally, print the SparkSession variable.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ae26fbe0d1fd:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Colab</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# Now, load the dataset. For that I'm using the .csv module.
#
# And passing the inferSchema parameter = true; it will enable the Spark to automatically determine the data type for each column but it has to go over the data once.If we didn't set inderShema to True, then are the tokens are considered as string.

# %%
df = spark.read.csv("/content/data.csv", header=True, inferSchema= True)
df.printSchema()
# Out:
# root
#  |-- customerID: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- SeniorCitizen: integer (nullable = true)
#  |-- Partner: string (nullable = true)
#  |-- Dependents: string (nullable = true)
#  |-- tenure: integer (nullable = true)
#  |-- PhoneService: string (nullable = true)
#  |-- MultipleLines: string (nullable = true)
#  |-- InternetService: string (nullable = true)
#  |-- OnlineSecurity: string (nullable = true)
#  |-- OnlineBackup: string (nullable = true)
#  |-- DeviceProtection: string (nullable = true)
#  |-- TechSupport: string (nullable = true)
#  |-- StreamingTV: string (nullable = true)
#  |-- StreamingMovies: string (nullable = true)
#  |-- Contract: string (nullable = true)
#  |-- PaperlessBilling: string (nullable = true)
#  |-- PaymentMethod: string (nullable = true)
#  |-- MonthlyCharges: double (nullable = true)
#  |-- TotalCharges: string (nullable = true)
#  |-- Churn: string (nullable = true)

# %% [markdown]
# **Performing actions on data
# operation 1: Finding number of rows in a data**

# %%
df.count()
# Out:
# 7043

# %% [markdown]
# **operation2: Finding First Row**

# %%
df.first()
# Out:
# Row(customerID='7590-VHVEG', gender='Female', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=1, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=29.85, TotalCharges='29.85', Churn='No')

# %% [markdown]
# **Operation 3: Finding Required rows using take function**
#
# ---

# %%
df.take(5)
# Out:
# [Row(customerID='7590-VHVEG', gender='Female', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=1, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=29.85, TotalCharges='29.85', Churn='No'),
#  Row(customerID='5575-GNVDE', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=34, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='Yes', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='One year', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=56.95, TotalCharges='1889.5', Churn='No'),
#  Row(customerID='3668-QPYBK', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=2, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Mailed check', MonthlyCharges=53.85, TotalCharges='108.15', Churn='Yes'),
#  Row(customerID='7795-CFOCW', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=45, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='One year', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=42.3, TotalCharges='1840.75', Churn='No'),
#  Row(customerID='9237-HQITU', gender='Female', SeniorCitizen=0, Partner='No', Dependents='No', tenure=2, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=70.7, TotalCharges='151.65', Churn='Yes')]

# %% [markdown]
# **Performing transformations on data
# Operation 1: Replacing the data**

# %%
df.replace('Male',None).show()
# Out:
# +----------+------+-------------+-------+----------+------+------------+----------------+---------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+--------------+----------------+--------------------+--------------+------------+-----+
# |customerID|gender|SeniorCitizen|Partner|Dependents|tenure|PhoneService|   MultipleLines|InternetService|     OnlineSecurity|       OnlineBackup|   DeviceProtection|        TechSupport|        StreamingTV|    StreamingMovies|      Contract|PaperlessBilling|       PaymentMethod|MonthlyCharges|TotalCharges|Churn|
# +----------+------+-------------+-------+----------+------+------------+----------------+---------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+--------------+----------------+--------------------+--------------+------------+-----+
# |7590-VHVEG|Female|            0|    Yes|        No|     1|          No|No phone service|            DSL|                 No|                Yes|                 No|                 No|                 No|                 No|Month-to-month|             Yes|    Electronic check|         29.85|       29.85|   No|
# |5575-GNVDE|  null|            0|     No|        No|    34|         Yes|              No|            DSL|                Yes|                 No|                Yes|                 No|                 No|                 No|      One year|              No|        Mailed check|         56.95|      1889.5|   No|
# |3668-QPYBK|  null|            0|     No|        No|     2|         Yes|              No|            DSL|                Yes|                Yes|                 No|                 No|                 No|                 No|Month-to-month|             Yes|        Mailed check|         53.85|      108.15|  Yes|
# |7795-CFOCW|  null|            0|     No|        No|    45|          No|No phone service|            DSL|                Yes|                 No|                Yes|                Yes|                 No|                 No|      One year|              No|Bank transfer (au...|          42.3|     1840.75|   No|
# |9237-HQITU|Female|            0|     No|        No|     2|         Yes|              No|    Fiber optic|                 No|                 No|                 No|                 No|                 No|                 No|Month-to-month|             Yes|    Electronic check|          70.7|      151.65|  Yes|
# |9305-CDSKC|Female|            0|     No|        No|     8|         Yes|             Yes|    Fiber optic|                 No|                 No|                Yes|                 No|                Yes|                Yes|Month-to-month|             Yes|    Electronic check|         99.65|       820.5|  Yes|
# |1452-KIOVK|  null|            0|     No|       Yes|    22|         Yes|             Yes|    Fiber optic|                 No|                Yes|                 No|                 No|                Yes|                 No|Month-to-month|             Yes|Credit card (auto...|          89.1|      1949.4|   No|
# |6713-OKOMC|Female|            0|     No|        No|    10|          No|No phone service|            DSL|                Yes|                 No|                 No|                 No|                 No|                 No|Month-to-month|              No|        Mailed check|         29.75|       301.9|   No|
# |7892-POOKP|Female|            0|    Yes|        No|    28|         Yes|             Yes|    Fiber optic|                 No|                 No|                Yes|                Yes|                Yes|                Yes|Month-to-month|             Yes|    Electronic check|         104.8|     3046.05|  Yes|
# |6388-TABGU|  null|            0|     No|       Yes|    62|         Yes|              No|            DSL|                Yes|                Yes|                 No|                 No|                 No|                 No|      One year|              No|Bank transfer (au...|         56.15|     3487.95|   No|
# |9763-GRSKD|  null|            0|    Yes|       Yes|    13|         Yes|              No|            DSL|                Yes|                 No|                 No|                 No|                 No|                 No|Month-to-month|             Yes|        Mailed check|         49.95|      587.45|   No|
# |7469-LKBCI|  null|            0|     No|        No|    16|         Yes|              No|             No|No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|      Two year|              No|Credit card (auto...|         18.95|       326.8|   No|
# |8091-TTVAX|  null|            0|    Yes|        No|    58|         Yes|             Yes|    Fiber optic|                 No|                 No|                Yes|                 No|                Yes|                Yes|      One year|              No|Credit card (auto...|        100.35|      5681.1|   No|
# |0280-XJGEX|  null|            0|     No|        No|    49|         Yes|             Yes|    Fiber optic|                 No|                Yes|                Yes|                 No|                Yes|                Yes|Month-to-month|             Yes|Bank transfer (au...|         103.7|      5036.3|  Yes|
# |5129-JLPIS|  null|            0|     No|        No|    25|         Yes|              No|    Fiber optic|                Yes|                 No|                Yes|                Yes|                Yes|                Yes|Month-to-month|             Yes|    Electronic check|         105.5|     2686.05|   No|
# |3655-SNQYZ|Female|            0|    Yes|       Yes|    69|         Yes|             Yes|    Fiber optic|                Yes|                Yes|                Yes|                Yes|                Yes|                Yes|      Two year|              No|Credit card (auto...|        113.25|     7895.15|   No|
# |8191-XWSZG|Female|            0|     No|        No|    52|         Yes|              No|             No|No internet service|No internet service|No internet service|No internet service|No internet service|No internet service|      One year|              No|        Mailed check|         20.65|     1022.95|   No|
# |9959-WOFKT|  null|            0|     No|       Yes|    71|         Yes|             Yes|    Fiber optic|                Yes|                 No|                Yes|                 No|                Yes|                Yes|      Two year|              No|Bank transfer (au...|         106.7|     7382.25|   No|
# |4190-MFLUW|Female|            0|    Yes|       Yes|    10|         Yes|              No|            DSL|                 No|                 No|                Yes|                Yes|                 No|                 No|Month-to-month|              No|Credit card (auto...|          55.2|      528.35|  Yes|
# |4183-MYFRB|Female|            0|     No|        No|    21|         Yes|              No|    Fiber optic|                 No|                Yes|                Yes|                 No|                 No|                Yes|Month-to-month|             Yes|    Electronic check|         90.05|      1862.9|   No|
# +----------+------+-------------+-------+----------+------+------------+----------------+---------------+-------------------+-------------------+-------------------+-------------------+-------------------+-------------------+--------------+----------------+--------------------+--------------+------------+-----+
# only showing top 20 rows

# %% [markdown]
# **Operation 2: Finding required data using filter**

# %%
df.filter(df.gender == 'Male').collect()
# Out:
# [Row(customerID='5575-GNVDE', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=34, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='Yes', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='One year', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=56.95, TotalCharges='1889.5', Churn='No'),
#  Row(customerID='3668-QPYBK', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=2, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Mailed check', MonthlyCharges=53.85, TotalCharges='108.15', Churn='Yes'),
#  Row(customerID='7795-CFOCW', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=45, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='One year', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=42.3, TotalCharges='1840.75', Churn='No'),
#  Row(customerID='1452-KIOVK', gender='Male', SeniorCitizen=0, Partner='No', Dependents='Yes', tenure=22, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=89.1, TotalCharges='1949.4', Churn='No'),
#  Row(customerID='6388-TABGU', gender='Male', SeniorCitizen=0, Partner='No', Dependents='Yes', tenure=62, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='One year', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=56.15, TotalCharges='3487.95', Churn='No'),
#  Row(customerID='9763-GRSKD', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=13, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Mailed check', MonthlyCharges=49.95, TotalCharges='587.45', Churn='No'),
#  Row(customerID='7469-LKBCI', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=16, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='No', PaymentMethod='Credit card (automatic)', MonthlyCharges=18.95, TotalCharges='326.8', Churn='No'),
#  Row(customerID='8091-TTVAX', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=58, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='Yes', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='One year', PaperlessBilling='No', PaymentMethod='Credit card (automatic)', MonthlyCharges=100.35, TotalCharges='5681.1', Churn='No'),
#  Row(customerID='0280-XJGEX', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=49, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=103.7, TotalCharges='5036.3', Churn='Yes'),
#  Row(customerID='5129-JLPIS', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=25, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=105.5, TotalCharges='2686.05', Churn='No'),
#  Row(customerID='9959-WOFKT', gender='Male', SeniorCitizen=0, Partner='No', Dependents='Yes', tenure=71, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='Yes', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=106.7, TotalCharges='7382.25', Churn='No'),
#  Row(customerID='8779-QRDMV', gender='Male', SeniorCitizen=1, Partner='No', Dependents='No', tenure=1, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='Yes', TechSupport='No', StreamingTV='No', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=39.65, TotalCharges='39.65', Churn='Yes'),
#  Row(customerID='1680-VDCWW', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=12, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='One year', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=19.8, TotalCharges='202.25', Churn='No'),
#  Row(customerID='1066-JKSGK', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=20.15, TotalCharges='20.15', Churn='Yes'),
#  Row(customerID='6322-HRPFA', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=49, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='No', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Credit card (automatic)', MonthlyCharges=59.6, TotalCharges='2970.3', Churn='No'),
#  Row(customerID='6467-CHFZW', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=47, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=99.35, TotalCharges='4749.15', Churn='Yes'),
#  Row(customerID='8665-UTDHZ', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=1, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Electronic check', MonthlyCharges=30.2, TotalCharges='30.2', Churn='Yes'),
#  Row(customerID='5248-YGIJN', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=72, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=90.25, TotalCharges='6369.45', Churn='No'),
#  Row(customerID='4929-XIHVW', gender='Male', SeniorCitizen=1, Partner='Yes', Dependents='No', tenure=2, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='Yes', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=95.5, TotalCharges='181.65', Churn='No'),
#  Row(customerID='7310-EGVHZ', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=20.2, TotalCharges='20.2', Churn='No'),
#  Row(customerID='3413-BMNZE', gender='Male', SeniorCitizen=1, Partner='No', Dependents='No', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=45.25, TotalCharges='45.25', Churn='No'),
#  Row(customerID='6047-YHPVI', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=5, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=69.7, TotalCharges='316.9', Churn='Yes'),
#  Row(customerID='5380-WJKOV', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=34, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=106.35, TotalCharges='3549.25', Churn='Yes'),
#  Row(customerID='8865-TNMNX', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=10, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='One year', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=49.55, TotalCharges='475.7', Churn='No'),
#  Row(customerID='5948-UJZLF', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=2, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=49.25, TotalCharges='97', Churn='No'),
#  Row(customerID='7639-LIAYI', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=52, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='No', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=79.75, TotalCharges='4217.8', Churn='No'),
#  Row(customerID='1658-BYGOY', gender='Male', SeniorCitizen=1, Partner='No', Dependents='No', tenure=18, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=95.45, TotalCharges='1752.55', Churn='Yes'),
#  Row(customerID='5067-XJQFU', gender='Male', SeniorCitizen=1, Partner='Yes', Dependents='Yes', tenure=66, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='One year', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=108.45, TotalCharges='7076.35', Churn='No'),
#  Row(customerID='1215-FIGMP', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=60, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=89.9, TotalCharges='5450.7', Churn='No'),
#  Row(customerID='0526-SXDJP', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=72, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Two year', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=42.1, TotalCharges='2962', Churn='No'),
#  Row(customerID='8627-ZYGSZ', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=47, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='One year', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=78.9, TotalCharges='3650.35', Churn='No'),
#  Row(customerID='7410-OIEDU', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=10, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='Yes', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Mailed check', MonthlyCharges=79.85, TotalCharges='887.35', Churn='No'),
#  Row(customerID='2273-QCKXA', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=49.05, TotalCharges='49.05', Churn='No'),
#  Row(customerID='1891-QRQSA', gender='Male', SeniorCitizen=1, Partner='Yes', Dependents='Yes', tenure=64, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=111.6, TotalCharges='7099', Churn='No'),
#  Row(customerID='8028-PNXHQ', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=62, PhoneService='Yes', MultipleLines='Yes', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=24.25, TotalCharges='1424.6', Churn='No'),
#  Row(customerID='0191-ZHSKZ', gender='Male', SeniorCitizen=1, Partner='No', Dependents='No', tenure=30, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=74.75, TotalCharges='2111.3', Churn='No'),
#  Row(customerID='4445-ZJNMU', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=9, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=99.3, TotalCharges='918.75', Churn='No'),
#  Row(customerID='3016-KSVCP', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=29, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=33.75, TotalCharges='1009.25', Churn='No'),
#  Row(customerID='4767-HZZHQ', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=30, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=82.05, TotalCharges='2570.2', Churn='No'),
#  Row(customerID='2424-WVHPL', gender='Male', SeniorCitizen=1, Partner='No', Dependents='No', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Electronic check', MonthlyCharges=74.7, TotalCharges='74.7', Churn='No'),
#  Row(customerID='7233-PAHHL', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=66, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Mailed check', MonthlyCharges=84.0, TotalCharges='5714.25', Churn='No'),
#  Row(customerID='9848-JQJTX', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=72, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=100.9, TotalCharges='7459.05', Churn='No'),
#  Row(customerID='9803-FTJCG', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=71, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='No', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='One year', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=66.85, TotalCharges='4748.7', Churn='No'),
#  Row(customerID='0278-YXOOG', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=5, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=21.05, TotalCharges='113.85', Churn='Yes'),
#  Row(customerID='3212-KXOCR', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=52, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=21.0, TotalCharges='1107.2', Churn='No'),
#  Row(customerID='6380-ARCEH', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=20.2, TotalCharges='20.2', Churn='No'),
#  Row(customerID='7123-WQUHX', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=38, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='No', Contract='One year', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=95.0, TotalCharges='3605.6', Churn='No'),
#  Row(customerID='3192-NQECA', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=68, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=110.0, TotalCharges='7611.85', Churn='Yes'),
#  Row(customerID='6180-YBIQI', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=5, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=24.3, TotalCharges='100.2', Churn='No'),
#  Row(customerID='8597-CWYHH', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=43, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='One year', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=94.35, TotalCharges='3921.3', Churn='No'),
#  Row(customerID='2848-YXSMW', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=72, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='No', PaymentMethod='Credit card (automatic)', MonthlyCharges=19.4, TotalCharges='1363.25', Churn='No'),
#  Row(customerID='0486-HECZI', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=55, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=96.75, TotalCharges='5238.9', Churn='Yes'),
#  Row(customerID='3071-VBYPO', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=3, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Electronic check', MonthlyCharges=89.85, TotalCharges='248.4', Churn='No'),
#  Row(customerID='9445-ZUEQE', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=27, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=85.2, TotalCharges='2151.6', Churn='No'),
#  Row(customerID='0404-SWRVG', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=3, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=74.4, TotalCharges='229.55', Churn='Yes'),
#  Row(customerID='4622-YNKIJ', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=33, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='No', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='No', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=88.95, TotalCharges='3027.65', Churn='No'),
#  Row(customerID='6734-PSBAW', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=72, PhoneService='Yes', MultipleLines='Yes', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=23.55, TotalCharges='1723.95', Churn='No'),
#  Row(customerID='3930-ZGWVE', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=19.75, TotalCharges='19.75', Churn='No'),
#  Row(customerID='2639-UGMAZ', gender='Male', SeniorCitizen=1, Partner='No', Dependents='No', tenure=71, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='One year', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=56.45, TotalCharges='3985.35', Churn='No'),
#  Row(customerID='8587-XYZSF', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=67, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='Two year', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=50.55, TotalCharges='3260.1', Churn='No'),
#  Row(customerID='3091-FYHKI', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=1, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=35.45, TotalCharges='35.45', Churn='Yes'),
#  Row(customerID='2372-HWUHI', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=2, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Electronic check', MonthlyCharges=44.35, TotalCharges='81.25', Churn='Yes'),
#  Row(customerID='6217-KDYWC', gender='Male', SeniorCitizen=0, Partner='No', Dependents='Yes', tenure=57, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Mailed check', MonthlyCharges=19.6, TotalCharges='1170.55', Churn='No'),
#  Row(customerID='2636-SJDOU', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=64, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='One year', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=84.3, TotalCharges='5289.05', Churn='No'),
#  Row(customerID='1131-QQZEB', gender='Male', SeniorCitizen=1, Partner='Yes', Dependents='No', tenure=71, PhoneService='Yes', MultipleLines='Yes', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=23.95, TotalCharges='1756.2', Churn='No'),
#  Row(customerID='6837-BJYDQ', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=3, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='One year', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=19.6, TotalCharges='61.35', Churn='No'),
#  Row(customerID='2135-RXIHG', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=45.65, TotalCharges='45.65', Churn='Yes'),
#  Row(customerID='6440-DKQGE', gender='Male', SeniorCitizen=0, Partner='No', Dependents='Yes', tenure=30, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='No', StreamingTV='Yes', StreamingMovies='No', Contract='One year', PaperlessBilling='No', PaymentMethod='Credit card (automatic)', MonthlyCharges=64.5, TotalCharges='1929.95', Churn='No'),
#  Row(customerID='3466-BYAVD', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=15, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='No', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Mailed check', MonthlyCharges=69.5, TotalCharges='1071.4', Churn='No'),
#  Row(customerID='3874-EQOEP', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=7, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=95.0, TotalCharges='655.5', Churn='Yes'),
#  Row(customerID='9073-ZZIAY', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=62, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='No', PaymentMethod='Electronic check', MonthlyCharges=86.1, TotalCharges='5215.25', Churn='No'),
#  Row(customerID='2749-CTKAJ', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=22, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='One year', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=20.15, TotalCharges='419.9', Churn='No'),
#  Row(customerID='6371-NZYEG', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=16, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='Yes', TechSupport='No', StreamingTV='Yes', StreamingMovies='No', Contract='Two year', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=64.25, TotalCharges='1024', Churn='No'),
#  Row(customerID='7554-NEWDD', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=10, PhoneService='Yes', MultipleLines='Yes', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=25.7, TotalCharges='251.6', Churn='No'),
#  Row(customerID='4648-YPBTM', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=53, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='No', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=73.9, TotalCharges='3958.25', Churn='No'),
#  Row(customerID='6345-FZOQH', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=69, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=19.9, TotalCharges='1363.45', Churn='No'),
#  Row(customerID='5997-OPVFA', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=72, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=89.05, TotalCharges='6254.45', Churn='No'),
#  Row(customerID='3445-HXXGF', gender='Male', SeniorCitizen=1, Partner='Yes', Dependents='No', tenure=58, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='No', StreamingTV='No', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=45.3, TotalCharges='2651.2', Churn='Yes'),
#  Row(customerID='7654-YWJUF', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=43, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='One year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=84.25, TotalCharges='3539.25', Churn='No'),
#  Row(customerID='6727-IOTLZ', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=14, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=81.95, TotalCharges='1181.75', Churn='No'),
#  Row(customerID='3712-PKXZA', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=61, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='One year', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=20.55, TotalCharges='1252', Churn='No'),
#  Row(customerID='9367-WXLCH', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=8, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=84.5, TotalCharges='662.65', Churn='Yes'),
#  Row(customerID='5524-KHNJP', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=33, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='Yes', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='One year', PaperlessBilling='No', PaymentMethod='Credit card (automatic)', MonthlyCharges=74.75, TotalCharges='2453.3', Churn='No'),
#  Row(customerID='4827-USJHP', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=20, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Mailed check', MonthlyCharges=51.8, TotalCharges='1023.85', Churn='No'),
#  Row(customerID='8167-GJLRN', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=3, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Electronic check', MonthlyCharges=30.4, TotalCharges='82.15', Churn='No'),
#  Row(customerID='7100-FQPRV', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=43, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='No', TechSupport='Yes', StreamingTV='No', StreamingMovies='Yes', Contract='One year', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=71.9, TotalCharges='3173.35', Churn='No'),
#  Row(customerID='2472-OVKUP', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=6, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='No', StreamingTV='No', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=91.0, TotalCharges='531', Churn='Yes'),
#  Row(customerID='2146-EGVDT', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=59, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='No', PaymentMethod='Credit card (automatic)', MonthlyCharges=19.3, TotalCharges='1192.7', Churn='No'),
#  Row(customerID='9178-JHUVJ', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=24, PhoneService='Yes', MultipleLines='Yes', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=24.1, TotalCharges='587.4', Churn='No'),
#  Row(customerID='6168-YBYNP', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=59, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=111.35, TotalCharges='6519.75', Churn='No'),
#  Row(customerID='7255-SSFBC', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=72, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=112.25, TotalCharges='8041.65', Churn='No'),
#  Row(customerID='3645-DEYGF', gender='Male', SeniorCitizen=0, Partner='No', Dependents='Yes', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=20.75, TotalCharges='20.75', Churn='No'),
#  Row(customerID='3363-DTIVD', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=71, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='Yes', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='No', PaymentMethod='Electronic check', MonthlyCharges=105.55, TotalCharges='7405.5', Churn='No'),
#  Row(customerID='7018-WBJNK', gender='Male', SeniorCitizen=0, Partner='No', Dependents='Yes', tenure=13, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=78.3, TotalCharges='1033.95', Churn='No'),
#  Row(customerID='9142-KZXOP', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=44, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Credit card (automatic)', MonthlyCharges=68.85, TotalCharges='2958.95', Churn='No'),
#  Row(customerID='6348-SNFUS', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=72, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='No', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=55.45, TotalCharges='4179.2', Churn='No'),
#  Row(customerID='1285-OKIPP', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Electronic check', MonthlyCharges=79.9, TotalCharges='79.9', Churn='Yes'),
#  Row(customerID='1347-KTTTA', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=64, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='One year', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=102.45, TotalCharges='6654.1', Churn='No'),
#  Row(customerID='7841-TZDMQ', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=2, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=46.0, TotalCharges='84.5', Churn='Yes'),
#  Row(customerID='7157-SMCFK', gender='Male', SeniorCitizen=0, Partner='No', Dependents='Yes', tenure=61, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=19.75, TotalCharges='1124.2', Churn='No'),
#  Row(customerID='2504-DSHIH', gender='Male', SeniorCitizen=1, Partner='Yes', Dependents='No', tenure=23, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Electronic check', MonthlyCharges=86.8, TotalCharges='1975.85', Churn='No'),
#  Row(customerID='9286-BHDQG', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=72, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='Two year', PaperlessBilling='No', PaymentMethod='Credit card (automatic)', MonthlyCharges=45.25, TotalCharges='3139.8', Churn='No'),
#  Row(customerID='0230-WEQUW', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=66, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='No', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=56.6, TotalCharges='3789.2', Churn='No'),
#  Row(customerID='2040-LDIWQ', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=65, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=84.2, TotalCharges='5324.5', Churn='No'),
# ...
#  Row(customerID='3466-WAESX', gender='Male', SeniorCitizen=0, Partner='No', Dependents='Yes', tenure=16, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=69.1, TotalCharges='1083.7', Churn='No'),
#  Row(customerID='3638-VBZTA', gender='Male', SeniorCitizen=0, Partner='No', Dependents='Yes', tenure=68, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='No', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=86.5, TotalCharges='5882.75', Churn='No'),
#  Row(customerID='7459-IMVYU', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=38, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Electronic check', MonthlyCharges=69.95, TotalCharges='2657.55', Churn='No'),
#  Row(customerID='7776-QWNFX', gender='Male', SeniorCitizen=1, Partner='Yes', Dependents='No', tenure=30, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=50.4, TotalCharges='1527.5', Churn='Yes'),
#  Row(customerID='8563-OYMQY', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=17, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='No', StreamingTV='No', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=90.95, TotalCharges='1612.2', Churn='No'),
#  Row(customerID='0754-EEBDC', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=4, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=19.9, TotalCharges='76.65', Churn='No'),
#  Row(customerID='1951-IEYXM', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=72, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=90.6, TotalCharges='6441.85', Churn='No'),
#  Row(customerID='3318-NMQXL', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=3, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=92.0, TotalCharges='266.8', Churn='No'),
#  Row(customerID='3143-ILDAL', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=56, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='Yes', StreamingTV='No', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=94.45, TotalCharges='5124.6', Churn='Yes'),
#  Row(customerID='2361-FJWNO', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=40, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='No', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='One year', PaperlessBilling='No', PaymentMethod='Credit card (automatic)', MonthlyCharges=36.0, TotalCharges='1382.9', Churn='No'),
#  Row(customerID='8232-UTFOZ', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=69, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='No', PaymentMethod='Credit card (automatic)', MonthlyCharges=19.95, TotalCharges='1399.35', Churn='No'),
#  Row(customerID='3750-YHRYO', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=7, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='One year', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=20.65, TotalCharges='150', Churn='No'),
#  Row(customerID='0129-QMPDR', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=44, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='One year', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=20.5, TotalCharges='865.05', Churn='No'),
#  Row(customerID='3221-CJMSG', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=24, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=51.1, TotalCharges='1269.6', Churn='No'),
#  Row(customerID='2801-NISEI', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=24, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='No', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Electronic check', MonthlyCharges=54.95, TotalCharges='1348.5', Churn='No'),
#  Row(customerID='3946-MHCZW', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='Yes', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=50.9, TotalCharges='50.9', Churn='Yes'),
#  Row(customerID='4623-ZKHLY', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='No', tenure=22, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=20.45, TotalCharges='471.55', Churn='No'),
#  Row(customerID='6732-VAILE', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=70, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='No', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=85.95, TotalCharges='5931.75', Churn='No'),
#  Row(customerID='8201-AAXCB', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=25, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='Yes', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Electronic check', MonthlyCharges=60.35, TotalCharges='1404.65', Churn='No'),
#  Row(customerID='7696-CFTAT', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=37, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=19.8, TotalCharges='726.1', Churn='No'),
#  Row(customerID='6651-AZVTJ', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=49, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='Yes', TechSupport='No', StreamingTV='Yes', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=99.8, TotalCharges='4872.45', Churn='Yes'),
#  Row(customerID='4566-GOLUK', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=47, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=107.35, TotalCharges='5118.95', Churn='Yes'),
#  Row(customerID='2018-QKYGT', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=81.05, TotalCharges='81.05', Churn='No'),
#  Row(customerID='2792-VPPET', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=3, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Electronic check', MonthlyCharges=20.5, TotalCharges='76.95', Churn='No'),
#  Row(customerID='3247-MHJKM', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=20.2, TotalCharges='20.2', Churn='No'),
#  Row(customerID='1964-SVLEA', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=20, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='One year', PaperlessBilling='Yes', PaymentMethod='Mailed check', MonthlyCharges=19.7, TotalCharges='415.9', Churn='No'),
#  Row(customerID='8267-KFGYD', gender='Male', SeniorCitizen=0, Partner='No', Dependents='Yes', tenure=1, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Mailed check', MonthlyCharges=21.05, TotalCharges='21.05', Churn='No'),
#  Row(customerID='4890-VMUAV', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=63, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='Yes', OnlineBackup='Yes', DeviceProtection='Yes', TechSupport='Yes', StreamingTV='No', StreamingMovies='No', Contract='One year', PaperlessBilling='No', PaymentMethod='Electronic check', MonthlyCharges=71.5, TotalCharges='4576.3', Churn='No'),
#  Row(customerID='9261-WDCAF', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=3, PhoneService='Yes', MultipleLines='No', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='Yes', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=54.65, TotalCharges='189.1', Churn='No'),
#  Row(customerID='3764-MNMOI', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=46, PhoneService='Yes', MultipleLines='No', InternetService='No', OnlineSecurity='No internet service', OnlineBackup='No internet service', DeviceProtection='No internet service', TechSupport='No internet service', StreamingTV='No internet service', StreamingMovies='No internet service', Contract='Two year', PaperlessBilling='No', PaymentMethod='Credit card (automatic)', MonthlyCharges=19.2, TotalCharges='908.15', Churn='No'),
#  Row(customerID='7442-YGZFK', gender='Male', SeniorCitizen=0, Partner='No', Dependents='No', tenure=1, PhoneService='Yes', MultipleLines='Yes', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=49.8, TotalCharges='49.8', Churn='No'),
#  Row(customerID='0420-BWTPW', gender='Male', SeniorCitizen=0, Partner='No', Dependents='Yes', tenure=8, PhoneService='No', MultipleLines='No phone service', InternetService='DSL', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='No', TechSupport='No', StreamingTV='No', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='No', PaymentMethod='Mailed check', MonthlyCharges=25.5, TotalCharges='215.2', Churn='Yes'),
#  Row(customerID='7449-HVPIV', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=55, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='No', OnlineBackup='No', DeviceProtection='Yes', TechSupport='No', StreamingTV='Yes', StreamingMovies='No', Contract='Month-to-month', PaperlessBilling='Yes', PaymentMethod='Credit card (automatic)', MonthlyCharges=90.4, TotalCharges='5099.15', Churn='No'),
#  Row(customerID='8466-PZBLH', gender='Male', SeniorCitizen=0, Partner='Yes', Dependents='Yes', tenure=67, PhoneService='Yes', MultipleLines='Yes', InternetService='Fiber optic', OnlineSecurity='Yes', OnlineBackup='No', DeviceProtection='No', TechSupport='Yes', StreamingTV='Yes', StreamingMovies='Yes', Contract='Two year', PaperlessBilling='No', PaymentMethod='Bank transfer (automatic)', MonthlyCharges=104.6, TotalCharges='6885.75', Churn='No'),
#  ...]

# %% [markdown]
# **Opearation 3: Grouping the data and showing count.**

# %%
op=df.groupBy('gender').count()
op.show()
# Out:
# +------+-----+
# |gender|count|
# +------+-----+
# |Female| 3488|
# |  Male| 3555|
# +------+-----+
